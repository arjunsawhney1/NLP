# %% [markdown]
# # Introduction
#
# In this notebook, I will implement an exhaustive NLP Pipeline that is able to process text data, correct spellings, and extract keywords and ngrams from multiple languages

# %%
import warnings
warnings.filterwarnings('ignore')

# Preprocessing
import numpy as np
import pandas as pd
import nltk
import re
import string
import html
import unicodedata
import blocks

# NLP Pipeline
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords 
from nltk.corpus import wordnet
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from collections import Counter
from textblob import TextBlob
from sklearn.feature_extraction.text import CountVectorizer

# Visualization
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Data
#
# We will be looking at two different datasets for this project.

# %% [markdown]
# ### Amazon Reviews
# https://www.kaggle.com/snap/amazon-fine-food-reviews/version/2
#
# This dataset consists of reviews of fine foods from amazon. The data spans a period of more than 10 years, including all ~500,000 reviews up to October 2012. For the purposes of this demonstration, we will use only 1000 rows

# %%
df1 = pd.read_csv('Reviews.csv').head(1000)
df1 = df1[['Text']]
df1.head(10)
# Out:
#                                                 Text
# 0  I have bought several of the Vitality canned d...
# 1  Product arrived labeled as Jumbo Salted Peanut...
# 2  This is a confection that has been around a fe...
# 3  If you are looking for the secret ingredient i...
# 4  Great taffy at a great price.  There was a wid...
# 5  I got a wild hair for taffy and ordered this f...
# 6  This saltwater taffy had great flavors and was...
# 7  This taffy is so good.  It is very soft and ch...
# 8  Right now I'm mostly just sprouting this so my...
# 9  This is a very healthy dog food. Good for thei...

# %% [markdown]
# Let's inspect a long review that has html elements and a relatively large vocabulary

# %%
df1['Text'][508]
# Out:
# 'These are perhaps the worst chips that have ever gone into my mouth.<br /><br />For my entire life Sour Cream & Onion (and in this case "& Chive") chips were my favorite. Recently Kettle brand Honey Dijon Mustard took that slot. So when I found out they had sour cream & onion I just had to try them.<br /><br />As soon as I opened the bag the chips smelled of powdered milk. And indeed each chip is coated with a powdered sour cream that is just awful. It tastes like rancid milk. Not just sour, but like sour cream that when rancid. The powdery texture is also extremely unappealing. I basically hated these chips. I would not recommend these chips to anyone unless they had a particular affinity for a powdery, chalky texture on a chip, with a rancid (and onion flavor) and I have a hard time believing that person exists.<br /><br />I plan on contacting Kettle and sharing my thoughts with them. Hopefully they\'ll reassess the seasoning on these otherwise wonderful kettle style chips.'

# %% [markdown]
# ### SMS Spam Collection
# https://www.dt.fee.unicamp.br/~tiago/smsspamcollection/
#
# The SMS Spam Collection v.1 is a public set of SMS labeled messages that have been collected for mobile phone spam research. It has one collection composed by 5,574 real and non-enconded messages, tagged according to being legitimate (ham) or spam. For the purposes of this demonstration, we will use only 5000 rows

# %%
with open('SMSSpamCollection.txt') as f:
    lines = f.readlines()
    df2 = pd.DataFrame(lines).head(1000)
    df2.columns = ['Text']
    df2[['SMS', 'Text']] = df2.Text.str.split('\t', expand=True)
    
df2.head(10)
# Out:
#                                                 Text   SMS
# 0  Go until jurong point, crazy.. Available only ...   ham
# 1                    Ok lar... Joking wif u oni...\n   ham
# 2  Free entry in 2 a wkly comp to win FA Cup fina...  spam
# 3  U dun say so early hor... U c already then say...   ham
# 4  Nah I don't think he goes to usf, he lives aro...   ham
# 5  FreeMsg Hey there darling it's been 3 week's n...  spam
# 6  Even my brother is not like to speak with me. ...   ham
# 7  As per your request 'Melle Melle (Oru Minnamin...   ham
# 8  WINNER!! As a valued network customer you have...  spam
# 9  Had your mobile 11 months or more? U R entitle...  spam

# %% [markdown]
# Let's inspect an SMS that is riddled with grammatical errors

# %%
df2['Text'][244]
# Out:
# "Although i told u dat i'm into baig face watches now but i really like e watch u gave cos it's fr u. Thanx 4 everything dat u've done today, i'm touched...\n"

# %% [markdown]
# # <b>Pre-Processing Pipeline</b>
#
# Read function docstrings to understand what each function does

# %%
def clean_math(text):
    '''Clean all math elements'''
    cleanr = re.compile('<math>(.*?)<\/math>')
    clean_text = re.sub(cleanr, ' ', text)
    return ' '.join(clean_text.split())

def clean_html(text):
    '''Clean all HTML elements'''
    cleanr = re.compile('<.*?>')
    clean_text = re.sub(cleanr, ' ', text)
    clean_text = html.unescape(clean_text)
    clean_text = unicodedata.normalize('NFKD', clean_text).encode('ASCII','ignore').decode('ASCII')    
    return ' '.join(clean_text.split())

def clean_unicode(text):
    '''Clean text by unicode block. Remove unwanted symbols and emojis'''
    cleanr = re.compile(
        "(["
        "\U0001F1E0-\U0001F1FF"  # flags (iOS)
        "\U0001F300-\U0001F5FF"  # symbols & pictographs
        "\U0001F600-\U0001F64F"  # emoticons
        "\U0001F680-\U0001F6FF"  # transport & map symbols
        "\U0001F700-\U0001F77F"  # alchemical symbols
        "\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
        "\U000027F0-\U000027FF"  # Supplemental Arrows-A
        "\U00002900-\U0000297F"  # Supplemental Arrows-B
        "\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
        "\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
        "\U0001FA00-\U0001FA6F"  # Chess Symbols
        "\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
        "\U00002702-\U000027B0"  # Dingbats
        "\U00002000-\U0000206F"  # General Punctuation
        "\U00002E00-\U00002E7F"  # Supplemental Punctuation
        "\U00003000-\U0000303F"  # CJK Symbols and Punctuation
        "\U00002200-\U000022FF"  # Mathematical Operators
        "\U0001D400-\U0001D7FF"  # Mathematical Alphanumeric Symbols        
        "\U000020A0-\U000020CF"  # Currency Symbols
        "\U00002100-\U0000214F"  # Combining Diacritical Marks 
        "\U000020A0-\U000020CF"  # Letterlike Symbols
        "\U00002190-\U000021FF"  # Arrows 
        "\U00002B00-\U00002BFF"  # Miscellaneous Symbols and Arrows 
        "\U000025A0-\U000025FF"  # Geometric Shapes 
        "\U00002600-\U000026FF"  # Miscellaneous Symbols         
        "\U00002070-\U0000209F"  # Superscripts and Subscripts
        "\U00002150-\U0000218F"  # Number Forms
        "\U00000250-\U000002AF"  # IPA Extensions
        "\U0000E000-\U0000F8FF"  # Private Use Area
        "\U0000FE00-\U0000FE0F"  # Variation Selectors
        "\U00002300-\U000023FF"  # Miscellaneous Technical
        "\U000002B0-\U000002FF"  # Spacing Modifier Letters
        "\U00002500-\U0000257F"  # Box Drawing
        "])"
    )
    
    clean_text = re.sub(cleanr, ' ', text)
    return ' '.join(clean_text.split())

def clean_punct(text):
    '''Remove all punctuation'''
    return text.translate(str.maketrans(' ', ' ', string.punctuation))

def clean_digits(text):
    '''Remove all digits'''
    return text.translate(str.maketrans(' ', ' ', string.digits))

def process_text(text):
    text = clean_math(text)
    text = clean_html(text)
    text = clean_unicode(text)
    text = clean_punct(text)
    text = clean_digits(text)
    text = text.strip()
    text = text.lower()
    return text

def label_unicode(row):
    '''Label the document by the unicode block it belongs to'''
    seq = Counter(row['Text'])
    if len(seq) > 0:
        return blocks.of(max(seq))
    else:
        return
        
def clean_text(df):
    '''Combine all pre-processing into one function'''
    df['Text'] = df['Text'].map(lambda x: process_text(x))
    df['unicode'] = df.apply(label_unicode, axis = 1)
    df.dropna(inplace=True)
    
    return df

# %% [markdown]
# ### Amazon Review Text

# %%
df1 = clean_text(df1)
df1.head(10)
# Out:
#                                                 Text      unicode
# 0  i have bought several of the vitality canned d...  BASIC_LATIN
# 1  product arrived labeled as jumbo salted peanut...  BASIC_LATIN
# 2  this is a confection that has been around a fe...  BASIC_LATIN
# 3  if you are looking for the secret ingredient i...  BASIC_LATIN
# 4  great taffy at a great price there was a wide ...  BASIC_LATIN
# 5  i got a wild hair for taffy and ordered this f...  BASIC_LATIN
# 6  this saltwater taffy had great flavors and was...  BASIC_LATIN
# 7  this taffy is so good it is very soft and chew...  BASIC_LATIN
# 8  right now im mostly just sprouting this so my ...  BASIC_LATIN
# 9  this is a very healthy dog food good for their...  BASIC_LATIN

# %%
df1['Text'][508]
# Out:
# 'these are perhaps the worst chips that have ever gone into my mouth for my entire life sour cream  onion and in this case  chive chips were my favorite recently kettle brand honey dijon mustard took that slot so when i found out they had sour cream  onion i just had to try them as soon as i opened the bag the chips smelled of powdered milk and indeed each chip is coated with a powdered sour cream that is just awful it tastes like rancid milk not just sour but like sour cream that when rancid the powdery texture is also extremely unappealing i basically hated these chips i would not recommend these chips to anyone unless they had a particular affinity for a powdery chalky texture on a chip with a rancid and onion flavor and i have a hard time believing that person exists i plan on contacting kettle and sharing my thoughts with them hopefully theyll reassess the seasoning on these otherwise wonderful kettle style chips'

# %% [markdown]
# ### SMS Text

# %%
df2 = clean_text(df2)
df2.head(10)
# Out:
#                                                 Text   SMS      unicode
# 0  go until jurong point crazy available only in ...   ham  BASIC_LATIN
# 1                            ok lar joking wif u oni   ham  BASIC_LATIN
# 2  free entry in  a wkly comp to win fa cup final...  spam  BASIC_LATIN
# 3        u dun say so early hor u c already then say   ham  BASIC_LATIN
# 4  nah i dont think he goes to usf he lives aroun...   ham  BASIC_LATIN
# 5  freemsg hey there darling its been  weeks now ...  spam  BASIC_LATIN
# 6  even my brother is not like to speak with me t...   ham  BASIC_LATIN
# 7  as per your request melle melle oru minnaminun...   ham  BASIC_LATIN
# 8  winner as a valued network customer you have b...  spam  BASIC_LATIN
# 9  had your mobile  months or more u r entitled t...  spam  BASIC_LATIN

# %%
df2['Text'][244]
# Out:
# 'although i told u dat im into baig face watches now but i really like e watch u gave cos its fr u thanx  everything dat uve done today im touched'

# %% [markdown]
# # Create Corpus Vocabulary
#
# In this section, we create a document vocabulary by filtering out stop words and using a CountVectorizer instance

# %%
def filter_docs(df):
    '''
    Create a vocabulary from all documents that only includes non-stopwords 
    that appear in atleast 2 documents and less than 90% of all documents
    '''
    stop = []
    lst = []

    # Find stopwords from all languages
    for language in stopwords.fileids():
        stop.extend(stopwords.words(language))
        
    # Only count non-stopwords that appear in atleast 5 documents and less than 80% of all documents
    cv = CountVectorizer(min_df = 5, max_df = 0.80, stop_words = stop)

    # Implement CountVectorizer by unicode block (language)
    for unicode in np.unique(df['unicode']):
        docs = df[df['unicode'] == unicode]['Text'].tolist()
        if len(docs) > 100:
            wcv = cv.fit_transform(docs)
            lst.extend(cv.vocabulary_.keys())

    vocab = set(lst)
    
    return vocab

# %% [markdown]
# # Extract Keywords
# In this section, we extract keywords from the text by filtering out stop words and words that are not in the vocabulary. The words are spell corrected and lemmatized to maintain context for phrase analysis

# %%
def create_kw_map(vocab):
    kw_map = dict()
    
    for word in vocab:
        if not wordnet.synsets(word):
            kw_map[word] = str(TextBlob(word).correct())            
    
    return kw_map

def extract_words(df, vocab, kw_map):
    '''
    Extract list of spell corrected and lemmatized keywords 
    from each document that is included in the vocabulary 
    '''
#     ps = PorterStemmer()
    lm = WordNetLemmatizer()
    
    # Tokenize
    df['Text'] = df['Text'].map(lambda x: nltk.word_tokenize(x))
    
    # Remove word if not in vocab
    df['Text'] = df['Text'].map(lambda x: list(filter(lambda w: w in vocab, x)))
    
    # Correct word spelling if incorrect
    df = df.replace(kw_map)
    
    # Lemmatize words
    df['Text'] = df['Text'].map(lambda x: list(map(lambda w: lm.lemmatize(w), x)))

#     Stem words (Instead of lemmatization)
#     df['Text'] = df['Text'].map(lambda x: list(map(lambda w: ps.stem(w), x)))

#     Select unique words (optional)
#     df['Text'] = df['Text'].map(lambda x: np.unique(x))
    
    return df

# %% [markdown]
# # Create N-grams
#
# Suppose we wish to analyse phrases as well as keywords. The functions below allow users to create n-grams either by specifying `n` or by generating all possible n-grams from 1 to `n-1` where `n` is the length of the phrase

# %%
def create_ngrams(n, tokens):
    ''' 
    Create list of n-grams from the input phrase
    '''
    if n == 1:
        return tokens
    else:
        ngrams = [tokens[i:i+n] for i in range(len(tokens)-1)]
        ngrams = [' '.join(ngram) for ngram in ngrams if len(ngram) == n]
        
        return ngrams
    
def create_all_ngrams(tokens):
    ''' 
    Create list of all n-grams from n=1 to n=len(phrase) from the input phrase
    '''
    out = []
    
    for n in range(1, len(tokens)):
        out.extend(create_ngrams(n, tokens))
        
    return out

# %% [markdown]
# # Results

# %% [markdown]
# ### Amazon Review Text

# %%
vocab1 = filter_docs(df1)
len(vocab1)
# Out:
# 1215

# %% [markdown]
# #### Spell Check Dictionary

# %%
kw_map1 = create_kw_map(vocab1)
kw_map1
# Out:
# {'ive': 'give',
#  'walmart': 'palmar',
#  'microbrews': 'microbes',
#  'shes': 'she',
#  'dont': 'dont',
#  'others': 'others',
#  'couldnt': 'couldn',
#  'pocky': 'rocky',
#  'bbq': 'by',
#  'else': 'else',
#  'youve': 'you',
#  'isnt': 'isn',
#  'youre': 'your',
#  'starbucks': 'starbucks',
#  'havent': 'haven',
#  'something': 'something',
#  'hey': 'hey',
#  'would': 'would',
#  'wouldnt': 'wouldn',
#  'glutenfree': 'glutenfree',
#  'thats': 'that',
#  'etc': 'etc',
#  'whenever': 'whenever',
#  'glycemic': 'glycerin',
#  'ahmad': 'ahead',
#  'crunchy': 'crutch',
#  'unless': 'unless',
#  'everyone': 'everyone',
#  'doesnt': 'doesn',
#  'could': 'could',
#  'didnt': 'didn',
#  'dissapointed': 'disappointed',
#  'everything': 'everything',
#  'trans': 'trans',
#  'anything': 'anything',
#  'although': 'although',
#  'habanero': 'habanero',
#  'mccanns': 'mccanns',
#  'twizzlers': 'twizzlers',
#  'youd': 'you',
#  'youll': 'you',
#  'without': 'without',
#  'germanstyle': 'germanstyle',
#  'steaz': 'steam',
#  'amazoncom': 'amazoncom',
#  'plockys': 'locks',
#  'oz': 'oz',
#  'cannot': 'cannot',
#  'andor': 'ardor',
#  'unmistakablea': 'unmistakable',
#  'numi': 'numb',
#  'yum': 'sum',
#  'arent': 'agent',
#  'carb': 'care',
#  'since': 'since',
#  'tassimo': 'tassimo',
#  'weve': 'were',
#  'annette': 'annette',
#  'theyre': 'there',
#  'wasnt': 'want',
#  'upon': 'upon',
#  'anyone': 'anyone',
#  'ramen': 'raven'}

# %%
df1 = extract_words(df1, vocab1, kw_map1)
df1.head(10)
# Out:
#                                                 Text      unicode
# 0  [bought, several, canned, food, product, found...  BASIC_LATIN
# 1  [product, arrived, salted, peanut, actually, s...  BASIC_LATIN
# 2  [around, light, nut, case, cut, tiny, sugar, t...  BASIC_LATIN
# 3  [looking, ingredient, believe, found, got, add...  BASIC_LATIN
# 4  [great, taffy, great, price, yummy, taffy, del...  BASIC_LATIN
# 5  [got, taffy, ordered, five, pound, bag, taffy,...  BASIC_LATIN
# 6  [taffy, great, flavor, soft, chewy, candy, wra...  BASIC_LATIN
# 7  [taffy, good, soft, chewy, flavor, amazing, wo...  BASIC_LATIN
# 8            [right, mostly, cat, eat, love, around]  BASIC_LATIN
# 9  [healthy, food, good, good, small, eats, amoun...  BASIC_LATIN

# %%
df1['Text'][508]
# Out:
# ['perhaps',
#  'worst',
#  'chip',
#  'ever',
#  'gone',
#  'mouth',
#  'entire',
#  'life',
#  'sour',
#  'cream',
#  'onion',
#  'case',
#  'chip',
#  'favorite',
#  'recently',
#  'kettle',
#  'brand',
#  'honey',
#  'dijon',
#  'mustard',
#  'took',
#  'found',
#  'sour',
#  'cream',
#  'onion',
#  'try',
#  'soon',
#  'opened',
#  'bag',
#  'chip',
#  'milk',
#  'chip',
#  'sour',
#  'cream',
#  'awful',
#  'taste',
#  'like',
#  'rancid',
#  'milk',
#  'sour',
#  'like',
#  'sour',
#  'cream',
#  'rancid',
#  'texture',
#  'extremely',
#  'chip',
#  'would',
#  'recommend',
#  'chip',
#  'anyone',
#  'unless',
#  'particular',
#  'texture',
#  'chip',
#  'rancid',
#  'onion',
#  'flavor',
#  'hard',
#  'time',
#  'person',
#  'plan',
#  'kettle',
#  'seasoning',
#  'otherwise',
#  'wonderful',
#  'kettle',
#  'style',
#  'chip']

# %%
create_all_ngrams(df1['Text'][508])
# Out:
# ['perhaps',
#  'worst',
#  'chip',
#  'ever',
#  'gone',
#  'mouth',
#  'entire',
#  'life',
#  'sour',
#  'cream',
#  'onion',
#  'case',
#  'chip',
#  'favorite',
#  'recently',
#  'kettle',
#  'brand',
#  'honey',
#  'dijon',
#  'mustard',
#  'took',
#  'found',
#  'sour',
#  'cream',
#  'onion',
#  'try',
#  'soon',
#  'opened',
#  'bag',
#  'chip',
#  'milk',
#  'chip',
#  'sour',
#  'cream',
#  'awful',
#  'taste',
#  'like',
#  'rancid',
#  'milk',
#  'sour',
#  'like',
#  'sour',
#  'cream',
#  'rancid',
#  'texture',
#  'extremely',
#  'chip',
#  'would',
#  'recommend',
#  'chip',
#  'anyone',
#  'unless',
#  'particular',
#  'texture',
#  'chip',
#  'rancid',
#  'onion',
#  'flavor',
#  'hard',
#  'time',
#  'person',
#  'plan',
#  'kettle',
#  'seasoning',
#  'otherwise',
#  'wonderful',
#  'kettle',
#  'style',
#  'chip',
#  'perhaps worst',
#  'worst chip',
#  'chip ever',
#  'ever gone',
#  'gone mouth',
#  'mouth entire',
#  'entire life',
#  'life sour',
#  'sour cream',
#  'cream onion',
#  'onion case',
#  'case chip',
#  'chip favorite',
#  'favorite recently',
#  'recently kettle',
#  'kettle brand',
#  'brand honey',
#  'honey dijon',
#  'dijon mustard',
#  'mustard took',
#  'took found',
#  'found sour',
#  'sour cream',
#  'cream onion',
#  'onion try',
#  'try soon',
#  'soon opened',
#  'opened bag',
#  'bag chip',
#  'chip milk',
#  'milk chip',
#  'chip sour',
#  'sour cream',
#  'cream awful',
#  'awful taste',
#  'taste like',
#  'like rancid',
#  'rancid milk',
#  'milk sour',
#  'sour like',
#  'like sour',
#  'sour cream',
#  'cream rancid',
#  'rancid texture',
#  'texture extremely',
#  'extremely chip',
#  'chip would',
#  'would recommend',
#  'recommend chip',
#  'chip anyone',
#  'anyone unless',
#  'unless particular',
#  'particular texture',
#  'texture chip',
#  'chip rancid',
#  'rancid onion',
#  'onion flavor',
#  'flavor hard',
#  'hard time',
#  'time person',
#  'person plan',
#  'plan kettle',
#  'kettle seasoning',
#  'seasoning otherwise',
#  'otherwise wonderful',
#  'wonderful kettle',
#  'kettle style',
#  'style chip',
#  'perhaps worst chip',
#  'worst chip ever',
#  'chip ever gone',
#  'ever gone mouth',
#  'gone mouth entire',
#  'mouth entire life',
#  'entire life sour',
#  'life sour cream',
#  'sour cream onion',
#  'cream onion case',
#  'onion case chip',
#  'case chip favorite',
#  'chip favorite recently',
#  'favorite recently kettle',
#  'recently kettle brand',
#  'kettle brand honey',
#  'brand honey dijon',
#  'honey dijon mustard',
#  'dijon mustard took',
#  'mustard took found',
#  'took found sour',
#  'found sour cream',
#  'sour cream onion',
#  'cream onion try',
#  'onion try soon',
#  'try soon opened',
#  'soon opened bag',
#  'opened bag chip',
#  'bag chip milk',
#  'chip milk chip',
#  'milk chip sour',
#  'chip sour cream',
#  'sour cream awful',
#  'cream awful taste',
#  'awful taste like',
#  'taste like rancid',
#  'like rancid milk',
#  'rancid milk sour',
#  'milk sour like',
#  'sour like sour',
#  'like sour cream',
#  'sour cream rancid',
#  'cream rancid texture',
#  'rancid texture extremely',
#  'texture extremely chip',
#  'extremely chip would',
#  'chip would recommend',
#  'would recommend chip',
#  'recommend chip anyone',
#  'chip anyone unless',
#  'anyone unless particular',
#  'unless particular texture',
#  'particular texture chip',
#  'texture chip rancid',
#  'chip rancid onion',
#  'rancid onion flavor',
#  'onion flavor hard',
#  'flavor hard time',
#  'hard time person',
#  'time person plan',
#  'person plan kettle',
#  'plan kettle seasoning',
#  'kettle seasoning otherwise',
#  'seasoning otherwise wonderful',
#  'otherwise wonderful kettle',
#  'wonderful kettle style',
#  'kettle style chip',
#  'perhaps worst chip ever',
#  'worst chip ever gone',
#  'chip ever gone mouth',
#  'ever gone mouth entire',
#  'gone mouth entire life',
#  'mouth entire life sour',
#  'entire life sour cream',
#  'life sour cream onion',
#  'sour cream onion case',
#  'cream onion case chip',
#  'onion case chip favorite',
#  'case chip favorite recently',
#  'chip favorite recently kettle',
#  'favorite recently kettle brand',
#  'recently kettle brand honey',
#  'kettle brand honey dijon',
#  'brand honey dijon mustard',
#  'honey dijon mustard took',
#  'dijon mustard took found',
#  'mustard took found sour',
#  'took found sour cream',
#  'found sour cream onion',
#  'sour cream onion try',
#  'cream onion try soon',
#  'onion try soon opened',
#  'try soon opened bag',
#  'soon opened bag chip',
#  'opened bag chip milk',
#  'bag chip milk chip',
#  'chip milk chip sour',
#  'milk chip sour cream',
#  'chip sour cream awful',
#  'sour cream awful taste',
#  'cream awful taste like',
#  'awful taste like rancid',
#  'taste like rancid milk',
#  'like rancid milk sour',
#  'rancid milk sour like',
#  'milk sour like sour',
#  'sour like sour cream',
#  'like sour cream rancid',
#  'sour cream rancid texture',
#  'cream rancid texture extremely',
#  'rancid texture extremely chip',
#  'texture extremely chip would',
#  'extremely chip would recommend',
#  'chip would recommend chip',
#  'would recommend chip anyone',
#  'recommend chip anyone unless',
#  'chip anyone unless particular',
#  'anyone unless particular texture',
#  'unless particular texture chip',
#  'particular texture chip rancid',
#  'texture chip rancid onion',
#  'chip rancid onion flavor',
#  'rancid onion flavor hard',
#  'onion flavor hard time',
#  'flavor hard time person',
#  'hard time person plan',
#  'time person plan kettle',
#  'person plan kettle seasoning',
#  'plan kettle seasoning otherwise',
#  'kettle seasoning otherwise wonderful',
#  'seasoning otherwise wonderful kettle',
#  'otherwise wonderful kettle style',
#  'wonderful kettle style chip',
#  'perhaps worst chip ever gone',
#  'worst chip ever gone mouth',
#  'chip ever gone mouth entire',
#  'ever gone mouth entire life',
#  'gone mouth entire life sour',
#  'mouth entire life sour cream',
#  'entire life sour cream onion',
#  'life sour cream onion case',
#  'sour cream onion case chip',
#  'cream onion case chip favorite',
#  'onion case chip favorite recently',
#  'case chip favorite recently kettle',
#  'chip favorite recently kettle brand',
#  'favorite recently kettle brand honey',
#  'recently kettle brand honey dijon',
#  'kettle brand honey dijon mustard',
#  'brand honey dijon mustard took',
#  'honey dijon mustard took found',
#  'dijon mustard took found sour',
#  'mustard took found sour cream',
#  'took found sour cream onion',
#  'found sour cream onion try',
#  'sour cream onion try soon',
#  'cream onion try soon opened',
#  'onion try soon opened bag',
#  'try soon opened bag chip',
#  'soon opened bag chip milk',
#  'opened bag chip milk chip',
#  'bag chip milk chip sour',
#  'chip milk chip sour cream',
#  'milk chip sour cream awful',
#  'chip sour cream awful taste',
#  'sour cream awful taste like',
#  'cream awful taste like rancid',
#  'awful taste like rancid milk',
#  'taste like rancid milk sour',
#  'like rancid milk sour like',
#  'rancid milk sour like sour',
#  'milk sour like sour cream',
#  'sour like sour cream rancid',
#  'like sour cream rancid texture',
#  'sour cream rancid texture extremely',
#  'cream rancid texture extremely chip',
#  'rancid texture extremely chip would',
#  'texture extremely chip would recommend',
#  'extremely chip would recommend chip',
#  'chip would recommend chip anyone',
#  'would recommend chip anyone unless',
#  'recommend chip anyone unless particular',
#  'chip anyone unless particular texture',
#  'anyone unless particular texture chip',
#  'unless particular texture chip rancid',
#  'particular texture chip rancid onion',
#  'texture chip rancid onion flavor',
#  'chip rancid onion flavor hard',
#  'rancid onion flavor hard time',
#  'onion flavor hard time person',
#  'flavor hard time person plan',
#  'hard time person plan kettle',
#  'time person plan kettle seasoning',
#  'person plan kettle seasoning otherwise',
#  'plan kettle seasoning otherwise wonderful',
#  'kettle seasoning otherwise wonderful kettle',
#  'seasoning otherwise wonderful kettle style',
#  'otherwise wonderful kettle style chip',
#  'perhaps worst chip ever gone mouth',
#  'worst chip ever gone mouth entire',
#  'chip ever gone mouth entire life',
#  'ever gone mouth entire life sour',
#  'gone mouth entire life sour cream',
#  'mouth entire life sour cream onion',
#  'entire life sour cream onion case',
#  'life sour cream onion case chip',
#  'sour cream onion case chip favorite',
#  'cream onion case chip favorite recently',
#  'onion case chip favorite recently kettle',
#  'case chip favorite recently kettle brand',
#  'chip favorite recently kettle brand honey',
#  'favorite recently kettle brand honey dijon',
#  'recently kettle brand honey dijon mustard',
#  'kettle brand honey dijon mustard took',
#  'brand honey dijon mustard took found',
#  'honey dijon mustard took found sour',
#  'dijon mustard took found sour cream',
#  'mustard took found sour cream onion',
#  'took found sour cream onion try',
#  'found sour cream onion try soon',
#  'sour cream onion try soon opened',
#  'cream onion try soon opened bag',
#  'onion try soon opened bag chip',
#  'try soon opened bag chip milk',
#  'soon opened bag chip milk chip',
#  'opened bag chip milk chip sour',
#  'bag chip milk chip sour cream',
#  'chip milk chip sour cream awful',
#  'milk chip sour cream awful taste',
#  'chip sour cream awful taste like',
#  'sour cream awful taste like rancid',
#  'cream awful taste like rancid milk',
#  'awful taste like rancid milk sour',
#  'taste like rancid milk sour like',
#  'like rancid milk sour like sour',
#  'rancid milk sour like sour cream',
#  'milk sour like sour cream rancid',
#  'sour like sour cream rancid texture',
#  'like sour cream rancid texture extremely',
#  'sour cream rancid texture extremely chip',
#  'cream rancid texture extremely chip would',
#  'rancid texture extremely chip would recommend',
#  'texture extremely chip would recommend chip',
#  'extremely chip would recommend chip anyone',
#  'chip would recommend chip anyone unless',
#  'would recommend chip anyone unless particular',
#  'recommend chip anyone unless particular texture',
#  'chip anyone unless particular texture chip',
#  'anyone unless particular texture chip rancid',
#  'unless particular texture chip rancid onion',
#  'particular texture chip rancid onion flavor',
#  'texture chip rancid onion flavor hard',
#  'chip rancid onion flavor hard time',
#  'rancid onion flavor hard time person',
#  'onion flavor hard time person plan',
#  'flavor hard time person plan kettle',
#  'hard time person plan kettle seasoning',
#  'time person plan kettle seasoning otherwise',
#  'person plan kettle seasoning otherwise wonderful',
#  'plan kettle seasoning otherwise wonderful kettle',
#  'kettle seasoning otherwise wonderful kettle style',
#  'seasoning otherwise wonderful kettle style chip',
#  'perhaps worst chip ever gone mouth entire',
#  'worst chip ever gone mouth entire life',
#  'chip ever gone mouth entire life sour',
#  'ever gone mouth entire life sour cream',
#  'gone mouth entire life sour cream onion',
#  'mouth entire life sour cream onion case',
#  'entire life sour cream onion case chip',
#  'life sour cream onion case chip favorite',
#  'sour cream onion case chip favorite recently',
#  'cream onion case chip favorite recently kettle',
#  'onion case chip favorite recently kettle brand',
#  'case chip favorite recently kettle brand honey',
#  'chip favorite recently kettle brand honey dijon',
#  'favorite recently kettle brand honey dijon mustard',
#  'recently kettle brand honey dijon mustard took',
#  'kettle brand honey dijon mustard took found',
#  'brand honey dijon mustard took found sour',
#  'honey dijon mustard took found sour cream',
#  'dijon mustard took found sour cream onion',
#  'mustard took found sour cream onion try',
#  'took found sour cream onion try soon',
#  'found sour cream onion try soon opened',
#  'sour cream onion try soon opened bag',
#  'cream onion try soon opened bag chip',
#  'onion try soon opened bag chip milk',
#  'try soon opened bag chip milk chip',
#  'soon opened bag chip milk chip sour',
#  'opened bag chip milk chip sour cream',
#  'bag chip milk chip sour cream awful',
#  'chip milk chip sour cream awful taste',
#  'milk chip sour cream awful taste like',
#  'chip sour cream awful taste like rancid',
#  'sour cream awful taste like rancid milk',
#  'cream awful taste like rancid milk sour',
#  'awful taste like rancid milk sour like',
#  'taste like rancid milk sour like sour',
#  'like rancid milk sour like sour cream',
#  'rancid milk sour like sour cream rancid',
#  'milk sour like sour cream rancid texture',
#  'sour like sour cream rancid texture extremely',
#  'like sour cream rancid texture extremely chip',
#  'sour cream rancid texture extremely chip would',
#  'cream rancid texture extremely chip would recommend',
#  'rancid texture extremely chip would recommend chip',
#  'texture extremely chip would recommend chip anyone',
#  'extremely chip would recommend chip anyone unless',
#  'chip would recommend chip anyone unless particular',
#  'would recommend chip anyone unless particular texture',
#  'recommend chip anyone unless particular texture chip',
#  'chip anyone unless particular texture chip rancid',
#  'anyone unless particular texture chip rancid onion',
#  'unless particular texture chip rancid onion flavor',
#  'particular texture chip rancid onion flavor hard',
#  'texture chip rancid onion flavor hard time',
#  'chip rancid onion flavor hard time person',
#  'rancid onion flavor hard time person plan',
#  'onion flavor hard time person plan kettle',
#  'flavor hard time person plan kettle seasoning',
#  'hard time person plan kettle seasoning otherwise',
#  'time person plan kettle seasoning otherwise wonderful',
#  'person plan kettle seasoning otherwise wonderful kettle',
#  'plan kettle seasoning otherwise wonderful kettle style',
#  'kettle seasoning otherwise wonderful kettle style chip',
#  'perhaps worst chip ever gone mouth entire life',
#  'worst chip ever gone mouth entire life sour',
#  'chip ever gone mouth entire life sour cream',
#  'ever gone mouth entire life sour cream onion',
#  'gone mouth entire life sour cream onion case',
#  'mouth entire life sour cream onion case chip',
#  'entire life sour cream onion case chip favorite',
#  'life sour cream onion case chip favorite recently',
#  'sour cream onion case chip favorite recently kettle',
#  'cream onion case chip favorite recently kettle brand',
#  'onion case chip favorite recently kettle brand honey',
#  'case chip favorite recently kettle brand honey dijon',
#  'chip favorite recently kettle brand honey dijon mustard',
#  'favorite recently kettle brand honey dijon mustard took',
#  'recently kettle brand honey dijon mustard took found',
#  'kettle brand honey dijon mustard took found sour',
#  'brand honey dijon mustard took found sour cream',
#  'honey dijon mustard took found sour cream onion',
#  'dijon mustard took found sour cream onion try',
#  'mustard took found sour cream onion try soon',
#  'took found sour cream onion try soon opened',
#  'found sour cream onion try soon opened bag',
#  'sour cream onion try soon opened bag chip',
#  'cream onion try soon opened bag chip milk',
#  'onion try soon opened bag chip milk chip',
#  'try soon opened bag chip milk chip sour',
#  'soon opened bag chip milk chip sour cream',
#  'opened bag chip milk chip sour cream awful',
#  'bag chip milk chip sour cream awful taste',
#  'chip milk chip sour cream awful taste like',
#  'milk chip sour cream awful taste like rancid',
#  'chip sour cream awful taste like rancid milk',
#  'sour cream awful taste like rancid milk sour',
#  'cream awful taste like rancid milk sour like',
#  'awful taste like rancid milk sour like sour',
#  'taste like rancid milk sour like sour cream',
#  'like rancid milk sour like sour cream rancid',
#  'rancid milk sour like sour cream rancid texture',
#  'milk sour like sour cream rancid texture extremely',
#  'sour like sour cream rancid texture extremely chip',
#  'like sour cream rancid texture extremely chip would',
#  'sour cream rancid texture extremely chip would recommend',
#  'cream rancid texture extremely chip would recommend chip',
#  'rancid texture extremely chip would recommend chip anyone',
#  'texture extremely chip would recommend chip anyone unless',
#  'extremely chip would recommend chip anyone unless particular',
#  'chip would recommend chip anyone unless particular texture',
#  'would recommend chip anyone unless particular texture chip',
#  'recommend chip anyone unless particular texture chip rancid',
#  'chip anyone unless particular texture chip rancid onion',
#  'anyone unless particular texture chip rancid onion flavor',
#  'unless particular texture chip rancid onion flavor hard',
#  'particular texture chip rancid onion flavor hard time',
#  'texture chip rancid onion flavor hard time person',
#  'chip rancid onion flavor hard time person plan',
#  'rancid onion flavor hard time person plan kettle',
#  'onion flavor hard time person plan kettle seasoning',
#  'flavor hard time person plan kettle seasoning otherwise',
#  'hard time person plan kettle seasoning otherwise wonderful',
#  'time person plan kettle seasoning otherwise wonderful kettle',
#  'person plan kettle seasoning otherwise wonderful kettle style',
#  'plan kettle seasoning otherwise wonderful kettle style chip',
#  'perhaps worst chip ever gone mouth entire life sour',
#  'worst chip ever gone mouth entire life sour cream',
#  'chip ever gone mouth entire life sour cream onion',
#  'ever gone mouth entire life sour cream onion case',
#  'gone mouth entire life sour cream onion case chip',
#  'mouth entire life sour cream onion case chip favorite',
#  'entire life sour cream onion case chip favorite recently',
#  'life sour cream onion case chip favorite recently kettle',
#  'sour cream onion case chip favorite recently kettle brand',
#  'cream onion case chip favorite recently kettle brand honey',
#  'onion case chip favorite recently kettle brand honey dijon',
#  'case chip favorite recently kettle brand honey dijon mustard',
#  'chip favorite recently kettle brand honey dijon mustard took',
#  'favorite recently kettle brand honey dijon mustard took found',
#  'recently kettle brand honey dijon mustard took found sour',
#  'kettle brand honey dijon mustard took found sour cream',
#  'brand honey dijon mustard took found sour cream onion',
#  'honey dijon mustard took found sour cream onion try',
#  'dijon mustard took found sour cream onion try soon',
#  'mustard took found sour cream onion try soon opened',
#  'took found sour cream onion try soon opened bag',
#  'found sour cream onion try soon opened bag chip',
#  'sour cream onion try soon opened bag chip milk',
#  'cream onion try soon opened bag chip milk chip',
#  'onion try soon opened bag chip milk chip sour',
#  'try soon opened bag chip milk chip sour cream',
#  'soon opened bag chip milk chip sour cream awful',
#  'opened bag chip milk chip sour cream awful taste',
#  'bag chip milk chip sour cream awful taste like',
#  'chip milk chip sour cream awful taste like rancid',
#  'milk chip sour cream awful taste like rancid milk',
#  'chip sour cream awful taste like rancid milk sour',
#  'sour cream awful taste like rancid milk sour like',
#  'cream awful taste like rancid milk sour like sour',
#  'awful taste like rancid milk sour like sour cream',
#  'taste like rancid milk sour like sour cream rancid',
#  'like rancid milk sour like sour cream rancid texture',
#  'rancid milk sour like sour cream rancid texture extremely',
#  'milk sour like sour cream rancid texture extremely chip',
#  'sour like sour cream rancid texture extremely chip would',
#  'like sour cream rancid texture extremely chip would recommend',
#  'sour cream rancid texture extremely chip would recommend chip',
#  'cream rancid texture extremely chip would recommend chip anyone',
#  'rancid texture extremely chip would recommend chip anyone unless',
#  'texture extremely chip would recommend chip anyone unless particular',
#  'extremely chip would recommend chip anyone unless particular texture',
#  'chip would recommend chip anyone unless particular texture chip',
#  'would recommend chip anyone unless particular texture chip rancid',
#  'recommend chip anyone unless particular texture chip rancid onion',
#  'chip anyone unless particular texture chip rancid onion flavor',
#  'anyone unless particular texture chip rancid onion flavor hard',
#  'unless particular texture chip rancid onion flavor hard time',
#  'particular texture chip rancid onion flavor hard time person',
#  'texture chip rancid onion flavor hard time person plan',
#  'chip rancid onion flavor hard time person plan kettle',
#  'rancid onion flavor hard time person plan kettle seasoning',
#  'onion flavor hard time person plan kettle seasoning otherwise',
#  'flavor hard time person plan kettle seasoning otherwise wonderful',
#  'hard time person plan kettle seasoning otherwise wonderful kettle',
#  'time person plan kettle seasoning otherwise wonderful kettle style',
#  'person plan kettle seasoning otherwise wonderful kettle style chip',
#  'perhaps worst chip ever gone mouth entire life sour cream',
#  'worst chip ever gone mouth entire life sour cream onion',
#  'chip ever gone mouth entire life sour cream onion case',
#  'ever gone mouth entire life sour cream onion case chip',
#  'gone mouth entire life sour cream onion case chip favorite',
#  'mouth entire life sour cream onion case chip favorite recently',
#  'entire life sour cream onion case chip favorite recently kettle',
#  'life sour cream onion case chip favorite recently kettle brand',
#  'sour cream onion case chip favorite recently kettle brand honey',
#  'cream onion case chip favorite recently kettle brand honey dijon',
#  'onion case chip favorite recently kettle brand honey dijon mustard',
#  'case chip favorite recently kettle brand honey dijon mustard took',
#  'chip favorite recently kettle brand honey dijon mustard took found',
#  'favorite recently kettle brand honey dijon mustard took found sour',
#  'recently kettle brand honey dijon mustard took found sour cream',
#  'kettle brand honey dijon mustard took found sour cream onion',
#  'brand honey dijon mustard took found sour cream onion try',
#  'honey dijon mustard took found sour cream onion try soon',
#  'dijon mustard took found sour cream onion try soon opened',
#  'mustard took found sour cream onion try soon opened bag',
#  'took found sour cream onion try soon opened bag chip',
#  'found sour cream onion try soon opened bag chip milk',
#  'sour cream onion try soon opened bag chip milk chip',
#  'cream onion try soon opened bag chip milk chip sour',
#  'onion try soon opened bag chip milk chip sour cream',
#  'try soon opened bag chip milk chip sour cream awful',
#  'soon opened bag chip milk chip sour cream awful taste',
#  'opened bag chip milk chip sour cream awful taste like',
#  'bag chip milk chip sour cream awful taste like rancid',
#  'chip milk chip sour cream awful taste like rancid milk',
#  'milk chip sour cream awful taste like rancid milk sour',
#  'chip sour cream awful taste like rancid milk sour like',
#  'sour cream awful taste like rancid milk sour like sour',
#  'cream awful taste like rancid milk sour like sour cream',
#  'awful taste like rancid milk sour like sour cream rancid',
#  'taste like rancid milk sour like sour cream rancid texture',
#  'like rancid milk sour like sour cream rancid texture extremely',
#  'rancid milk sour like sour cream rancid texture extremely chip',
#  'milk sour like sour cream rancid texture extremely chip would',
#  'sour like sour cream rancid texture extremely chip would recommend',
#  'like sour cream rancid texture extremely chip would recommend chip',
#  'sour cream rancid texture extremely chip would recommend chip anyone',
#  'cream rancid texture extremely chip would recommend chip anyone unless',
#  'rancid texture extremely chip would recommend chip anyone unless particular',
#  'texture extremely chip would recommend chip anyone unless particular texture',
#  'extremely chip would recommend chip anyone unless particular texture chip',
#  'chip would recommend chip anyone unless particular texture chip rancid',
#  'would recommend chip anyone unless particular texture chip rancid onion',
#  'recommend chip anyone unless particular texture chip rancid onion flavor',
#  'chip anyone unless particular texture chip rancid onion flavor hard',
#  'anyone unless particular texture chip rancid onion flavor hard time',
#  'unless particular texture chip rancid onion flavor hard time person',
#  'particular texture chip rancid onion flavor hard time person plan',
#  'texture chip rancid onion flavor hard time person plan kettle',
#  'chip rancid onion flavor hard time person plan kettle seasoning',
#  'rancid onion flavor hard time person plan kettle seasoning otherwise',
#  'onion flavor hard time person plan kettle seasoning otherwise wonderful',
#  'flavor hard time person plan kettle seasoning otherwise wonderful kettle',
#  'hard time person plan kettle seasoning otherwise wonderful kettle style',
#  'time person plan kettle seasoning otherwise wonderful kettle style chip',
#  'perhaps worst chip ever gone mouth entire life sour cream onion',
#  'worst chip ever gone mouth entire life sour cream onion case',
#  'chip ever gone mouth entire life sour cream onion case chip',
#  'ever gone mouth entire life sour cream onion case chip favorite',
#  'gone mouth entire life sour cream onion case chip favorite recently',
#  'mouth entire life sour cream onion case chip favorite recently kettle',
#  'entire life sour cream onion case chip favorite recently kettle brand',
#  'life sour cream onion case chip favorite recently kettle brand honey',
#  'sour cream onion case chip favorite recently kettle brand honey dijon',
#  'cream onion case chip favorite recently kettle brand honey dijon mustard',
#  'onion case chip favorite recently kettle brand honey dijon mustard took',
#  'case chip favorite recently kettle brand honey dijon mustard took found',
#  'chip favorite recently kettle brand honey dijon mustard took found sour',
#  'favorite recently kettle brand honey dijon mustard took found sour cream',
#  'recently kettle brand honey dijon mustard took found sour cream onion',
#  'kettle brand honey dijon mustard took found sour cream onion try',
#  'brand honey dijon mustard took found sour cream onion try soon',
#  'honey dijon mustard took found sour cream onion try soon opened',
#  'dijon mustard took found sour cream onion try soon opened bag',
#  'mustard took found sour cream onion try soon opened bag chip',
#  'took found sour cream onion try soon opened bag chip milk',
#  'found sour cream onion try soon opened bag chip milk chip',
#  'sour cream onion try soon opened bag chip milk chip sour',
#  'cream onion try soon opened bag chip milk chip sour cream',
#  'onion try soon opened bag chip milk chip sour cream awful',
#  'try soon opened bag chip milk chip sour cream awful taste',
#  'soon opened bag chip milk chip sour cream awful taste like',
#  'opened bag chip milk chip sour cream awful taste like rancid',
#  'bag chip milk chip sour cream awful taste like rancid milk',
#  'chip milk chip sour cream awful taste like rancid milk sour',
#  'milk chip sour cream awful taste like rancid milk sour like',
#  'chip sour cream awful taste like rancid milk sour like sour',
#  'sour cream awful taste like rancid milk sour like sour cream',
#  'cream awful taste like rancid milk sour like sour cream rancid',
#  'awful taste like rancid milk sour like sour cream rancid texture',
#  'taste like rancid milk sour like sour cream rancid texture extremely',
#  'like rancid milk sour like sour cream rancid texture extremely chip',
#  'rancid milk sour like sour cream rancid texture extremely chip would',
#  'milk sour like sour cream rancid texture extremely chip would recommend',
#  'sour like sour cream rancid texture extremely chip would recommend chip',
#  'like sour cream rancid texture extremely chip would recommend chip anyone',
#  'sour cream rancid texture extremely chip would recommend chip anyone unless',
#  'cream rancid texture extremely chip would recommend chip anyone unless particular',
#  'rancid texture extremely chip would recommend chip anyone unless particular texture',
#  'texture extremely chip would recommend chip anyone unless particular texture chip',
#  'extremely chip would recommend chip anyone unless particular texture chip rancid',
#  'chip would recommend chip anyone unless particular texture chip rancid onion',
#  'would recommend chip anyone unless particular texture chip rancid onion flavor',
#  'recommend chip anyone unless particular texture chip rancid onion flavor hard',
#  'chip anyone unless particular texture chip rancid onion flavor hard time',
#  'anyone unless particular texture chip rancid onion flavor hard time person',
#  'unless particular texture chip rancid onion flavor hard time person plan',
#  'particular texture chip rancid onion flavor hard time person plan kettle',
#  'texture chip rancid onion flavor hard time person plan kettle seasoning',
#  'chip rancid onion flavor hard time person plan kettle seasoning otherwise',
#  'rancid onion flavor hard time person plan kettle seasoning otherwise wonderful',
#  'onion flavor hard time person plan kettle seasoning otherwise wonderful kettle',
#  'flavor hard time person plan kettle seasoning otherwise wonderful kettle style',
#  'hard time person plan kettle seasoning otherwise wonderful kettle style chip',
#  'perhaps worst chip ever gone mouth entire life sour cream onion case',
#  'worst chip ever gone mouth entire life sour cream onion case chip',
#  'chip ever gone mouth entire life sour cream onion case chip favorite',
#  'ever gone mouth entire life sour cream onion case chip favorite recently',
#  'gone mouth entire life sour cream onion case chip favorite recently kettle',
#  'mouth entire life sour cream onion case chip favorite recently kettle brand',
#  'entire life sour cream onion case chip favorite recently kettle brand honey',
#  'life sour cream onion case chip favorite recently kettle brand honey dijon',
#  'sour cream onion case chip favorite recently kettle brand honey dijon mustard',
#  'cream onion case chip favorite recently kettle brand honey dijon mustard took',
#  'onion case chip favorite recently kettle brand honey dijon mustard took found',
#  'case chip favorite recently kettle brand honey dijon mustard took found sour',
#  'chip favorite recently kettle brand honey dijon mustard took found sour cream',
#  'favorite recently kettle brand honey dijon mustard took found sour cream onion',
#  'recently kettle brand honey dijon mustard took found sour cream onion try',
#  'kettle brand honey dijon mustard took found sour cream onion try soon',
#  'brand honey dijon mustard took found sour cream onion try soon opened',
#  'honey dijon mustard took found sour cream onion try soon opened bag',
#  'dijon mustard took found sour cream onion try soon opened bag chip',
#  'mustard took found sour cream onion try soon opened bag chip milk',
#  'took found sour cream onion try soon opened bag chip milk chip',
#  'found sour cream onion try soon opened bag chip milk chip sour',
#  'sour cream onion try soon opened bag chip milk chip sour cream',
#  'cream onion try soon opened bag chip milk chip sour cream awful',
#  'onion try soon opened bag chip milk chip sour cream awful taste',
#  'try soon opened bag chip milk chip sour cream awful taste like',
#  'soon opened bag chip milk chip sour cream awful taste like rancid',
#  'opened bag chip milk chip sour cream awful taste like rancid milk',
#  'bag chip milk chip sour cream awful taste like rancid milk sour',
#  'chip milk chip sour cream awful taste like rancid milk sour like',
#  'milk chip sour cream awful taste like rancid milk sour like sour',
#  'chip sour cream awful taste like rancid milk sour like sour cream',
#  'sour cream awful taste like rancid milk sour like sour cream rancid',
#  'cream awful taste like rancid milk sour like sour cream rancid texture',
#  'awful taste like rancid milk sour like sour cream rancid texture extremely',
#  'taste like rancid milk sour like sour cream rancid texture extremely chip',
#  'like rancid milk sour like sour cream rancid texture extremely chip would',
#  'rancid milk sour like sour cream rancid texture extremely chip would recommend',
#  'milk sour like sour cream rancid texture extremely chip would recommend chip',
#  'sour like sour cream rancid texture extremely chip would recommend chip anyone',
#  'like sour cream rancid texture extremely chip would recommend chip anyone unless',
#  'sour cream rancid texture extremely chip would recommend chip anyone unless particular',
#  'cream rancid texture extremely chip would recommend chip anyone unless particular texture',
#  'rancid texture extremely chip would recommend chip anyone unless particular texture chip',
#  'texture extremely chip would recommend chip anyone unless particular texture chip rancid',
#  'extremely chip would recommend chip anyone unless particular texture chip rancid onion',
#  'chip would recommend chip anyone unless particular texture chip rancid onion flavor',
#  'would recommend chip anyone unless particular texture chip rancid onion flavor hard',
#  'recommend chip anyone unless particular texture chip rancid onion flavor hard time',
#  'chip anyone unless particular texture chip rancid onion flavor hard time person',
#  'anyone unless particular texture chip rancid onion flavor hard time person plan',
#  'unless particular texture chip rancid onion flavor hard time person plan kettle',
#  'particular texture chip rancid onion flavor hard time person plan kettle seasoning',
#  'texture chip rancid onion flavor hard time person plan kettle seasoning otherwise',
#  'chip rancid onion flavor hard time person plan kettle seasoning otherwise wonderful',
#  'rancid onion flavor hard time person plan kettle seasoning otherwise wonderful kettle',
#  'onion flavor hard time person plan kettle seasoning otherwise wonderful kettle style',
#  'flavor hard time person plan kettle seasoning otherwise wonderful kettle style chip',
#  'perhaps worst chip ever gone mouth entire life sour cream onion case chip',
#  'worst chip ever gone mouth entire life sour cream onion case chip favorite',
#  'chip ever gone mouth entire life sour cream onion case chip favorite recently',
#  'ever gone mouth entire life sour cream onion case chip favorite recently kettle',
#  'gone mouth entire life sour cream onion case chip favorite recently kettle brand',
#  'mouth entire life sour cream onion case chip favorite recently kettle brand honey',
#  'entire life sour cream onion case chip favorite recently kettle brand honey dijon',
#  'life sour cream onion case chip favorite recently kettle brand honey dijon mustard',
#  'sour cream onion case chip favorite recently kettle brand honey dijon mustard took',
#  'cream onion case chip favorite recently kettle brand honey dijon mustard took found',
#  'onion case chip favorite recently kettle brand honey dijon mustard took found sour',
#  'case chip favorite recently kettle brand honey dijon mustard took found sour cream',
#  'chip favorite recently kettle brand honey dijon mustard took found sour cream onion',
#  'favorite recently kettle brand honey dijon mustard took found sour cream onion try',
#  'recently kettle brand honey dijon mustard took found sour cream onion try soon',
#  'kettle brand honey dijon mustard took found sour cream onion try soon opened',
#  'brand honey dijon mustard took found sour cream onion try soon opened bag',
#  'honey dijon mustard took found sour cream onion try soon opened bag chip',
#  'dijon mustard took found sour cream onion try soon opened bag chip milk',
#  'mustard took found sour cream onion try soon opened bag chip milk chip',
#  'took found sour cream onion try soon opened bag chip milk chip sour',
#  'found sour cream onion try soon opened bag chip milk chip sour cream',
#  'sour cream onion try soon opened bag chip milk chip sour cream awful',
#  'cream onion try soon opened bag chip milk chip sour cream awful taste',
#  'onion try soon opened bag chip milk chip sour cream awful taste like',
#  'try soon opened bag chip milk chip sour cream awful taste like rancid',
#  'soon opened bag chip milk chip sour cream awful taste like rancid milk',
#  'opened bag chip milk chip sour cream awful taste like rancid milk sour',
#  'bag chip milk chip sour cream awful taste like rancid milk sour like',
#  'chip milk chip sour cream awful taste like rancid milk sour like sour',
#  'milk chip sour cream awful taste like rancid milk sour like sour cream',
#  'chip sour cream awful taste like rancid milk sour like sour cream rancid',
#  'sour cream awful taste like rancid milk sour like sour cream rancid texture',
#  'cream awful taste like rancid milk sour like sour cream rancid texture extremely',
#  'awful taste like rancid milk sour like sour cream rancid texture extremely chip',
#  'taste like rancid milk sour like sour cream rancid texture extremely chip would',
#  'like rancid milk sour like sour cream rancid texture extremely chip would recommend',
#  'rancid milk sour like sour cream rancid texture extremely chip would recommend chip',
#  'milk sour like sour cream rancid texture extremely chip would recommend chip anyone',
#  'sour like sour cream rancid texture extremely chip would recommend chip anyone unless',
#  'like sour cream rancid texture extremely chip would recommend chip anyone unless particular',
#  'sour cream rancid texture extremely chip would recommend chip anyone unless particular texture',
#  'cream rancid texture extremely chip would recommend chip anyone unless particular texture chip',
#  'rancid texture extremely chip would recommend chip anyone unless particular texture chip rancid',
#  'texture extremely chip would recommend chip anyone unless particular texture chip rancid onion',
#  'extremely chip would recommend chip anyone unless particular texture chip rancid onion flavor',
#  'chip would recommend chip anyone unless particular texture chip rancid onion flavor hard',
#  'would recommend chip anyone unless particular texture chip rancid onion flavor hard time',
#  'recommend chip anyone unless particular texture chip rancid onion flavor hard time person',
#  'chip anyone unless particular texture chip rancid onion flavor hard time person plan',
#  'anyone unless particular texture chip rancid onion flavor hard time person plan kettle',
#  'unless particular texture chip rancid onion flavor hard time person plan kettle seasoning',
#  'particular texture chip rancid onion flavor hard time person plan kettle seasoning otherwise',
#  'texture chip rancid onion flavor hard time person plan kettle seasoning otherwise wonderful',
#  'chip rancid onion flavor hard time person plan kettle seasoning otherwise wonderful kettle',
#  'rancid onion flavor hard time person plan kettle seasoning otherwise wonderful kettle style',
#  'onion flavor hard time person plan kettle seasoning otherwise wonderful kettle style chip',
#  'perhaps worst chip ever gone mouth entire life sour cream onion case chip favorite',
#  'worst chip ever gone mouth entire life sour cream onion case chip favorite recently',
#  'chip ever gone mouth entire life sour cream onion case chip favorite recently kettle',
#  'ever gone mouth entire life sour cream onion case chip favorite recently kettle brand',
#  'gone mouth entire life sour cream onion case chip favorite recently kettle brand honey',
#  'mouth entire life sour cream onion case chip favorite recently kettle brand honey dijon',
#  'entire life sour cream onion case chip favorite recently kettle brand honey dijon mustard',
#  'life sour cream onion case chip favorite recently kettle brand honey dijon mustard took',
#  'sour cream onion case chip favorite recently kettle brand honey dijon mustard took found',
#  'cream onion case chip favorite recently kettle brand honey dijon mustard took found sour',
#  'onion case chip favorite recently kettle brand honey dijon mustard took found sour cream',
#  'case chip favorite recently kettle brand honey dijon mustard took found sour cream onion',
#  'chip favorite recently kettle brand honey dijon mustard took found sour cream onion try',
#  'favorite recently kettle brand honey dijon mustard took found sour cream onion try soon',
#  'recently kettle brand honey dijon mustard took found sour cream onion try soon opened',
#  'kettle brand honey dijon mustard took found sour cream onion try soon opened bag',
#  'brand honey dijon mustard took found sour cream onion try soon opened bag chip',
#  'honey dijon mustard took found sour cream onion try soon opened bag chip milk',
#  'dijon mustard took found sour cream onion try soon opened bag chip milk chip',
#  'mustard took found sour cream onion try soon opened bag chip milk chip sour',
#  'took found sour cream onion try soon opened bag chip milk chip sour cream',
#  'found sour cream onion try soon opened bag chip milk chip sour cream awful',
#  'sour cream onion try soon opened bag chip milk chip sour cream awful taste',
#  'cream onion try soon opened bag chip milk chip sour cream awful taste like',
#  'onion try soon opened bag chip milk chip sour cream awful taste like rancid',
#  'try soon opened bag chip milk chip sour cream awful taste like rancid milk',
#  'soon opened bag chip milk chip sour cream awful taste like rancid milk sour',
#  'opened bag chip milk chip sour cream awful taste like rancid milk sour like',
#  'bag chip milk chip sour cream awful taste like rancid milk sour like sour',
#  'chip milk chip sour cream awful taste like rancid milk sour like sour cream',
#  'milk chip sour cream awful taste like rancid milk sour like sour cream rancid',
#  'chip sour cream awful taste like rancid milk sour like sour cream rancid texture',
#  'sour cream awful taste like rancid milk sour like sour cream rancid texture extremely',
#  'cream awful taste like rancid milk sour like sour cream rancid texture extremely chip',
#  'awful taste like rancid milk sour like sour cream rancid texture extremely chip would',
#  'taste like rancid milk sour like sour cream rancid texture extremely chip would recommend',
#  'like rancid milk sour like sour cream rancid texture extremely chip would recommend chip',
#  'rancid milk sour like sour cream rancid texture extremely chip would recommend chip anyone',
#  'milk sour like sour cream rancid texture extremely chip would recommend chip anyone unless',
#  'sour like sour cream rancid texture extremely chip would recommend chip anyone unless particular',
#  'like sour cream rancid texture extremely chip would recommend chip anyone unless particular texture',
#  'sour cream rancid texture extremely chip would recommend chip anyone unless particular texture chip',
#  'cream rancid texture extremely chip would recommend chip anyone unless particular texture chip rancid',
#  'rancid texture extremely chip would recommend chip anyone unless particular texture chip rancid onion',
#  'texture extremely chip would recommend chip anyone unless particular texture chip rancid onion flavor',
#  'extremely chip would recommend chip anyone unless particular texture chip rancid onion flavor hard',
#  'chip would recommend chip anyone unless particular texture chip rancid onion flavor hard time',
#  'would recommend chip anyone unless particular texture chip rancid onion flavor hard time person',
#  'recommend chip anyone unless particular texture chip rancid onion flavor hard time person plan',
#  'chip anyone unless particular texture chip rancid onion flavor hard time person plan kettle',
#  'anyone unless particular texture chip rancid onion flavor hard time person plan kettle seasoning',
#  'unless particular texture chip rancid onion flavor hard time person plan kettle seasoning otherwise',
#  'particular texture chip rancid onion flavor hard time person plan kettle seasoning otherwise wonderful',
#  'texture chip rancid onion flavor hard time person plan kettle seasoning otherwise wonderful kettle',
#  'chip rancid onion flavor hard time person plan kettle seasoning otherwise wonderful kettle style',
#  'rancid onion flavor hard time person plan kettle seasoning otherwise wonderful kettle style chip',
#  'perhaps worst chip ever gone mouth entire life sour cream onion case chip favorite recently',
#  'worst chip ever gone mouth entire life sour cream onion case chip favorite recently kettle',
#  'chip ever gone mouth entire life sour cream onion case chip favorite recently kettle brand',
#  'ever gone mouth entire life sour cream onion case chip favorite recently kettle brand honey',
#  'gone mouth entire life sour cream onion case chip favorite recently kettle brand honey dijon',
#  'mouth entire life sour cream onion case chip favorite recently kettle brand honey dijon mustard',
#  'entire life sour cream onion case chip favorite recently kettle brand honey dijon mustard took',
#  'life sour cream onion case chip favorite recently kettle brand honey dijon mustard took found',
#  'sour cream onion case chip favorite recently kettle brand honey dijon mustard took found sour',
#  'cream onion case chip favorite recently kettle brand honey dijon mustard took found sour cream',
#  'onion case chip favorite recently kettle brand honey dijon mustard took found sour cream onion',
#  'case chip favorite recently kettle brand honey dijon mustard took found sour cream onion try',
#  'chip favorite recently kettle brand honey dijon mustard took found sour cream onion try soon',
#  'favorite recently kettle brand honey dijon mustard took found sour cream onion try soon opened',
#  'recently kettle brand honey dijon mustard took found sour cream onion try soon opened bag',
#  'kettle brand honey dijon mustard took found sour cream onion try soon opened bag chip',
#  'brand honey dijon mustard took found sour cream onion try soon opened bag chip milk',
#  'honey dijon mustard took found sour cream onion try soon opened bag chip milk chip',
#  'dijon mustard took found sour cream onion try soon opened bag chip milk chip sour',
#  'mustard took found sour cream onion try soon opened bag chip milk chip sour cream',
#  'took found sour cream onion try soon opened bag chip milk chip sour cream awful',
#  'found sour cream onion try soon opened bag chip milk chip sour cream awful taste',
#  'sour cream onion try soon opened bag chip milk chip sour cream awful taste like',
#  'cream onion try soon opened bag chip milk chip sour cream awful taste like rancid',
#  'onion try soon opened bag chip milk chip sour cream awful taste like rancid milk',
#  'try soon opened bag chip milk chip sour cream awful taste like rancid milk sour',
#  'soon opened bag chip milk chip sour cream awful taste like rancid milk sour like',
#  'opened bag chip milk chip sour cream awful taste like rancid milk sour like sour',
#  'bag chip milk chip sour cream awful taste like rancid milk sour like sour cream',
#  'chip milk chip sour cream awful taste like rancid milk sour like sour cream rancid',
#  'milk chip sour cream awful taste like rancid milk sour like sour cream rancid texture',
#  'chip sour cream awful taste like rancid milk sour like sour cream rancid texture extremely',
#  'sour cream awful taste like rancid milk sour like sour cream rancid texture extremely chip',
#  'cream awful taste like rancid milk sour like sour cream rancid texture extremely chip would',
#  'awful taste like rancid milk sour like sour cream rancid texture extremely chip would recommend',
#  'taste like rancid milk sour like sour cream rancid texture extremely chip would recommend chip',
#  'like rancid milk sour like sour cream rancid texture extremely chip would recommend chip anyone',
#  'rancid milk sour like sour cream rancid texture extremely chip would recommend chip anyone unless',
#  'milk sour like sour cream rancid texture extremely chip would recommend chip anyone unless particular',
#  'sour like sour cream rancid texture extremely chip would recommend chip anyone unless particular texture',
#  'like sour cream rancid texture extremely chip would recommend chip anyone unless particular texture chip',
#  'sour cream rancid texture extremely chip would recommend chip anyone unless particular texture chip rancid',
#  'cream rancid texture extremely chip would recommend chip anyone unless particular texture chip rancid onion',
#  'rancid texture extremely chip would recommend chip anyone unless particular texture chip rancid onion flavor',
#  'texture extremely chip would recommend chip anyone unless particular texture chip rancid onion flavor hard',
#  'extremely chip would recommend chip anyone unless particular texture chip rancid onion flavor hard time',
#  'chip would recommend chip anyone unless particular texture chip rancid onion flavor hard time person',
#  'would recommend chip anyone unless particular texture chip rancid onion flavor hard time person plan',
#  'recommend chip anyone unless particular texture chip rancid onion flavor hard time person plan kettle',
#  'chip anyone unless particular texture chip rancid onion flavor hard time person plan kettle seasoning',
#  'anyone unless particular texture chip rancid onion flavor hard time person plan kettle seasoning otherwise',
#  'unless particular texture chip rancid onion flavor hard time person plan kettle seasoning otherwise wonderful',
#  'particular texture chip rancid onion flavor hard time person plan kettle seasoning otherwise wonderful kettle',
#  'texture chip rancid onion flavor hard time person plan kettle seasoning otherwise wonderful kettle style',
#  'chip rancid onion flavor hard time person plan kettle seasoning otherwise wonderful kettle style chip',
#  'perhaps worst chip ever gone mouth entire life sour cream onion case chip favorite recently kettle',
#  'worst chip ever gone mouth entire life sour cream onion case chip favorite recently kettle brand',
#  'chip ever gone mouth entire life sour cream onion case chip favorite recently kettle brand honey',
#  'ever gone mouth entire life sour cream onion case chip favorite recently kettle brand honey dijon',
#  'gone mouth entire life sour cream onion case chip favorite recently kettle brand honey dijon mustard',
#  'mouth entire life sour cream onion case chip favorite recently kettle brand honey dijon mustard took',
#  'entire life sour cream onion case chip favorite recently kettle brand honey dijon mustard took found',
#  'life sour cream onion case chip favorite recently kettle brand honey dijon mustard took found sour',
#  'sour cream onion case chip favorite recently kettle brand honey dijon mustard took found sour cream',
#  'cream onion case chip favorite recently kettle brand honey dijon mustard took found sour cream onion',
#  'onion case chip favorite recently kettle brand honey dijon mustard took found sour cream onion try',
#  'case chip favorite recently kettle brand honey dijon mustard took found sour cream onion try soon',
#  'chip favorite recently kettle brand honey dijon mustard took found sour cream onion try soon opened',
#  'favorite recently kettle brand honey dijon mustard took found sour cream onion try soon opened bag',
#  'recently kettle brand honey dijon mustard took found sour cream onion try soon opened bag chip',
#  'kettle brand honey dijon mustard took found sour cream onion try soon opened bag chip milk',
#  'brand honey dijon mustard took found sour cream onion try soon opened bag chip milk chip',
#  'honey dijon mustard took found sour cream onion try soon opened bag chip milk chip sour',
#  'dijon mustard took found sour cream onion try soon opened bag chip milk chip sour cream',
#  'mustard took found sour cream onion try soon opened bag chip milk chip sour cream awful',
#  'took found sour cream onion try soon opened bag chip milk chip sour cream awful taste',
#  'found sour cream onion try soon opened bag chip milk chip sour cream awful taste like',
#  'sour cream onion try soon opened bag chip milk chip sour cream awful taste like rancid',
#  'cream onion try soon opened bag chip milk chip sour cream awful taste like rancid milk',
#  'onion try soon opened bag chip milk chip sour cream awful taste like rancid milk sour',
#  'try soon opened bag chip milk chip sour cream awful taste like rancid milk sour like',
#  'soon opened bag chip milk chip sour cream awful taste like rancid milk sour like sour',
#  'opened bag chip milk chip sour cream awful taste like rancid milk sour like sour cream',
#  'bag chip milk chip sour cream awful taste like rancid milk sour like sour cream rancid',
#  'chip milk chip sour cream awful taste like rancid milk sour like sour cream rancid texture',
#  'milk chip sour cream awful taste like rancid milk sour like sour cream rancid texture extremely',
#  'chip sour cream awful taste like rancid milk sour like sour cream rancid texture extremely chip',
#  'sour cream awful taste like rancid milk sour like sour cream rancid texture extremely chip would',
#  'cream awful taste like rancid milk sour like sour cream rancid texture extremely chip would recommend',
#  'awful taste like rancid milk sour like sour cream rancid texture extremely chip would recommend chip',
#  'taste like rancid milk sour like sour cream rancid texture extremely chip would recommend chip anyone',
#  'like rancid milk sour like sour cream rancid texture extremely chip would recommend chip anyone unless',
#  'rancid milk sour like sour cream rancid texture extremely chip would recommend chip anyone unless particular',
#  'milk sour like sour cream rancid texture extremely chip would recommend chip anyone unless particular texture',
#  'sour like sour cream rancid texture extremely chip would recommend chip anyone unless particular texture chip',
#  'like sour cream rancid texture extremely chip would recommend chip anyone unless particular texture chip rancid',
#  'sour cream rancid texture extremely chip would recommend chip anyone unless particular texture chip rancid onion',
#  'cream rancid texture extremely chip would recommend chip anyone unless particular texture chip rancid onion flavor',
#  'rancid texture extremely chip would recommend chip anyone unless particular texture chip rancid onion flavor hard',
#  'texture extremely chip would recommend chip anyone unless particular texture chip rancid onion flavor hard time',
#  'extremely chip would recommend chip anyone unless particular texture chip rancid onion flavor hard time person',
#  'chip would recommend chip anyone unless particular texture chip rancid onion flavor hard time person plan',
#  'would recommend chip anyone unless particular texture chip rancid onion flavor hard time person plan kettle',
#  'recommend chip anyone unless particular texture chip rancid onion flavor hard time person plan kettle seasoning',
#  'chip anyone unless particular texture chip rancid onion flavor hard time person plan kettle seasoning otherwise',
#  'anyone unless particular texture chip rancid onion flavor hard time person plan kettle seasoning otherwise wonderful',
#  'unless particular texture chip rancid onion flavor hard time person plan kettle seasoning otherwise wonderful kettle',
#  'particular texture chip rancid onion flavor hard time person plan kettle seasoning otherwise wonderful kettle style',
#  'texture chip rancid onion flavor hard time person plan kettle seasoning otherwise wonderful kettle style chip',
#  'perhaps worst chip ever gone mouth entire life sour cream onion case chip favorite recently kettle brand',
#  'worst chip ever gone mouth entire life sour cream onion case chip favorite recently kettle brand honey',
#  'chip ever gone mouth entire life sour cream onion case chip favorite recently kettle brand honey dijon',
#  'ever gone mouth entire life sour cream onion case chip favorite recently kettle brand honey dijon mustard',
#  'gone mouth entire life sour cream onion case chip favorite recently kettle brand honey dijon mustard took',
#  'mouth entire life sour cream onion case chip favorite recently kettle brand honey dijon mustard took found',
#  'entire life sour cream onion case chip favorite recently kettle brand honey dijon mustard took found sour',
#  'life sour cream onion case chip favorite recently kettle brand honey dijon mustard took found sour cream',
#  'sour cream onion case chip favorite recently kettle brand honey dijon mustard took found sour cream onion',
#  'cream onion case chip favorite recently kettle brand honey dijon mustard took found sour cream onion try',
#  'onion case chip favorite recently kettle brand honey dijon mustard took found sour cream onion try soon',
#  'case chip favorite recently kettle brand honey dijon mustard took found sour cream onion try soon opened',
#  'chip favorite recently kettle brand honey dijon mustard took found sour cream onion try soon opened bag',
#  'favorite recently kettle brand honey dijon mustard took found sour cream onion try soon opened bag chip',
#  'recently kettle brand honey dijon mustard took found sour cream onion try soon opened bag chip milk',
#  'kettle brand honey dijon mustard took found sour cream onion try soon opened bag chip milk chip',
#  ...]

# %% [raw]
# Original text:
# 'These are perhaps the worst chips that have ever gone into my mouth.<br /><br />For my entire life Sour Cream & Onion (and in this case "& Chive") chips were my favorite. Recently Kettle brand Honey Dijon Mustard took that slot. So when I found out they had sour cream & onion I just had to try them.<br /><br />As soon as I opened the bag the chips smelled of powdered milk. And indeed each chip is coated with a powdered sour cream that is just awful. It tastes like rancid milk. Not just sour, but like sour cream that when rancid. The powdery texture is also extremely unappealing. I basically hated these chips. I would not recommend these chips to anyone unless they had a particular affinity for a powdery, chalky texture on a chip, with a rancid (and onion flavor) and I have a hard time believing that person exists.<br /><br />I plan on contacting Kettle and sharing my thoughts with them. Hopefully they\'ll reassess the seasoning on these otherwise wonderful kettle style chips.'

# %% [markdown]
# ### SMS Text

# %%
vocab2 = filter_docs(df2)
len(vocab2)
# Out:
# 346

# %% [markdown]
# #### Spell Check Dictionary

# %%
kw_map2 = create_kw_map(vocab2)
kw_map2
# Out:
# {'ive': 'give',
#  'gonna': 'donna',
#  'hav': 'had',
#  'dont': 'dont',
#  'oso': 'so',
#  'dunno': 'funny',
#  'isnt': 'isn',
#  'youre': 'your',
#  'ah': 'ah',
#  'havent': 'haven',
#  'something': 'something',
#  'hey': 'hey',
#  'boytoy': 'boston',
#  'thanx': 'than',
#  'txt': 'txt',
#  'would': 'would',
#  'haha': 'hata',
#  'tscs': 'tss',
#  'thats': 'that',
#  'thk': 'the',
#  'ure': 'are',
#  'lar': 'war',
#  'doesnt': 'doesn',
#  'could': 'could',
#  'didnt': 'didn',
#  'gud': 'god',
#  'everything': 'everything',
#  'ard': 'and',
#  'st': 'st',
#  'pls': 'pus',
#  'anything': 'anything',
#  'wkly': 'wily',
#  'anytime': 'daytime',
#  'ppm': 'pp',
#  'ringtone': 'ringtone',
#  'jus': 'just',
#  'since': 'since',
#  'prob': 'probe',
#  'lol': 'll',
#  'luv': 'lui',
#  'yup': 'up',
#  'wanna': 'anna',
#  'nokia': 'nikita'}

# %%
df2 = extract_words(df2, vocab2, kw_map2)
df2.head(10)
# Out:
#                                                 Text   SMS      unicode
# 0                 [go, available, great, world, got]   ham  BASIC_LATIN
# 1                                          [ok, lar]   ham  BASIC_LATIN
# 2  [free, entry, wkly, win, st, may, text, receiv...  spam  BASIC_LATIN
# 3                    [dun, say, early, already, say]   ham  BASIC_LATIN
# 4                      [dont, think, around, though]   ham  BASIC_LATIN
# 5  [hey, word, back, id, like, still, ok, xxx, send]  spam  BASIC_LATIN
# 6                          [even, like, speak, like]   ham  BASIC_LATIN
# 7                                           [friend]   ham  BASIC_LATIN
# 8  [network, customer, selected, prize, claim, ca...  spam  BASIC_LATIN
# 9  [mobile, month, update, latest, camera, free, ...  spam  BASIC_LATIN

# %%
df2['Text'][244]
# Out:
# ['told', 'really', 'like', 'co', 'thanx', 'everything', 'done', 'today']

# %%
create_all_ngrams(df2['Text'][244])
# Out:
# ['told',
#  'really',
#  'like',
#  'co',
#  'thanx',
#  'everything',
#  'done',
#  'today',
#  'told really',
#  'really like',
#  'like co',
#  'co thanx',
#  'thanx everything',
#  'everything done',
#  'done today',
#  'told really like',
#  'really like co',
#  'like co thanx',
#  'co thanx everything',
#  'thanx everything done',
#  'everything done today',
#  'told really like co',
#  'really like co thanx',
#  'like co thanx everything',
#  'co thanx everything done',
#  'thanx everything done today',
#  'told really like co thanx',
#  'really like co thanx everything',
#  'like co thanx everything done',
#  'co thanx everything done today',
#  'told really like co thanx everything',
#  'really like co thanx everything done',
#  'like co thanx everything done today',
#  'told really like co thanx everything done',
#  'really like co thanx everything done today']

# %% [raw]
# Original text:
# "Although i told u dat i'm into baig face watches now but i really like e watch u gave cos it's fr u. Thanx 4 everything dat u've done today, i'm touched...\n"

# %% [markdown]
# With this pre-processing out of the way, the raw data is now ready for feature engineering and word embedding for applications like sentiment analysis etc.
